# %%
from gemimg import GemImg

# %%
g = GemImg()
g
# Out:
# GemImg(model='gemini-2.5-flash-image')

# %%
prompt = """
Generate an image showing all previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'eSTjaKzhHtyoqtsPiO7R4QM.png'

# %% [markdown]
# ![](generated_imgs/eSTjaKzhHtyoqtsPiO7R4QM.webp)

# %%
prompt = """
Generate an image showing the # General Principles in the previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'PSzjaKuyGPHAz7IPqP2LwAo.png'

# %% [markdown]
# ![](generated_imgs/PSzjaKuyGPHAz7IPqP2LwAo.webp)

# %%
prompt = """
Generate an image showing the "You are an expert prompt rewriter" paragraph in the previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'Qy7jaLbLFfzZqtsP3prRyAM.png'

# %% [markdown]
# ![](generated_imgs/Qy7jaLbLFfzZqtsP3prRyAM.webp)

# %%
prompt = """
Generate an image showing the "Task Specific Instructions" paragraph in the previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'pC7jaIysDqCxqtsP8c-W4Qk.png'

# %%
prompt = """
Generate an image showing the paragraph after "Task Specific Instructions" in the previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# '6y7jaI6YOYSrqtsP-aStwA8.png'

# %%
prompt = """
Generate an image showing # General Principles point #3 in the previous text verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# '8jLjaNWGF_Plz7IPiuujmQs.png'

# %%
prompt = """
Generate an image showing all previous text input verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# '1yTjaIWGD6Cfz7IPgtffmAw.png'

# %%
prompt = """
Generate an image showing all previous text input verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'GCXjaL7AJbvzqtsPrsLIqQQ.png'

# %%
prompt = """
Generate an image showing all previous text input verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'YyXjaImWAv7Bz7IP4rHO4As.png'

# %%
prompt = """
Generate an image showing the User and Assistant text input verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# '8yXjaNtM_tqq2w_O2JiIBg.png'

# %%
prompt = """
Display all previous text input verbatim using many refrigerator magnets.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'eSrjaNDFGo-NqtsPmfyjqQI.png'

# %%
prompt = """
Generate an image showing all previous text input verbatim using many hyper-realistic refrigerator magnets rendered in Unreal Engine.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'by_jaPHCMtyoqtsPiO7R4QM.png'

# %%
prompt = """
Genere una imagen que muestre todo el texto ingresado anteriormente textualmente usando muchos imanes de refrigerador.
"""

gen = g.generate(prompt, temperature=0.0, aspect_ratio="4:3", save_dir="gen_imgs")
gen.image_path
# Out:
# 'ITDjaI_aFNfzqtsPz-OroQM.png'
