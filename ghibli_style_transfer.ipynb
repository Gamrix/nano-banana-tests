# %%
from gemimg import GemImg
from PIL import Image

# %%
g = GemImg()
g
# Out:
# GemImg(model='gemini-2.5-flash-image')

# %%
selfie = Image.open("prompt_imgs/max_selfie.webp")

# %%
prompt = """
Make me into Studio Ghibli.
"""

gen = g.generate(prompt, selfie, aspect_ratio="1:1", save_dir="gen_imgs")
gen.image_path
# Out:
# 'h3cRaa74K6PUz7IPzLrYUA.png'

# %% [markdown]
# ![](generated_imgs/h3cRaa74K6PUz7IPzLrYUA.webp)
